# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
soil1 = pd.read_excel('../data/nsw-assessment-of-soil-health.xlsx', sheet_name='texture_analysis')
print(soil1.shape)
soil1.head(3)
# Out:
# (451, 14)
#       Site  < 0.060 um   0.06um-0.20um  0.20um-0.63um  0.06um-0.63um  \
# 0  CYP_001           0             0.0          3.674          3.674
# 1  CYP_002           0             0.0          3.311          3.311
# 2  CYP_003           0             0.0          1.831          1.831
#
#    0.63um-2.00um  2.00um-6.30um  6.30um-20.00um  20.00um-63.00um  >63.00um  \
# 0         18.059         20.094          13.121           19.861    25.191
# 1         14.786         17.700          15.294           22.992    25.918
# 2          8.651         19.092          24.099           30.016    16.311
#
#    > 2000.00um    Clay    Silt    Sand
# 0            0  25.407  53.076  21.517
# 1            0  21.408  55.986  22.606
# 2            0  12.313  73.207  14.480

# %%
soil2 = pd.read_excel('../data/nsw-assessment-of-soil-health.xlsx', sheet_name='soil_chemical_analysis')
print(soil2.shape)
soil2.head(3)
# Out:
# (2250, 7)
#       Community       SiteID    Site2  Colwell_P  Total_C%  Total_N%  \
# 0  Cypress pine  CYP_001_000  CYP_001     12.792  1.109756  0.107524
# 1  Cypress pine  CYP_001_050  CYP_001      7.216  1.233463  0.134746
# 2  Cypress pine  CYP_001_100  CYP_001     18.040  4.026537  0.308362
#
#    Bulk_density
# 0      2.061318
# 1      2.046539
# 2      1.428816

# %%
join = soil1.join(soil2.set_index('Site2')[['Community']], on='Site')

# join = soil1.join(soil2, how='left')

join.head()
# Out:
#       Site  < 0.060 um   0.06um-0.20um  0.20um-0.63um  0.06um-0.63um  \
# 0  CYP_001           0             0.0          3.674          3.674
# 0  CYP_001           0             0.0          3.674          3.674
# 0  CYP_001           0             0.0          3.674          3.674
# 0  CYP_001           0             0.0          3.674          3.674
# 0  CYP_001           0             0.0          3.674          3.674
#
#    0.63um-2.00um  2.00um-6.30um  6.30um-20.00um  20.00um-63.00um  >63.00um  \
# 0         18.059         20.094          13.121           19.861    25.191
# 0         18.059         20.094          13.121           19.861    25.191
# 0         18.059         20.094          13.121           19.861    25.191
# 0         18.059         20.094          13.121           19.861    25.191
# 0         18.059         20.094          13.121           19.861    25.191
#
#    > 2000.00um    Clay    Silt    Sand     Community
# ...

# %%
# pivot = pd.pivot_table(soil1,
#                        values='TRANSACTION_UNITS',
#                        index='Community',
#                        columns=['Clay', 'Silt', 'Sand'],
#                        aggfunc='sum',
#                        margins=True)

# #divide by total national sales for a given month
# #comment out next two lines to work with totals
# # for column in pivot:
# #     pivot[column] = pivot[column]/pivot['All']
# pivot

# %%
cp = join[join['Community'] == 'Cypress pine']
cp.head()
# Out:
#       Site  < 0.060 um   0.06um-0.20um  0.20um-0.63um  0.06um-0.63um  \
# 0  CYP_001           0             0.0          3.674          3.674
# 0  CYP_001           0             0.0          3.674          3.674
# 0  CYP_001           0             0.0          3.674          3.674
# 0  CYP_001           0             0.0          3.674          3.674
# 0  CYP_001           0             0.0          3.674          3.674
#
#    0.63um-2.00um  2.00um-6.30um  6.30um-20.00um  20.00um-63.00um  >63.00um  \
# 0         18.059         20.094          13.121           19.861    25.191
# 0         18.059         20.094          13.121           19.861    25.191
# 0         18.059         20.094          13.121           19.861    25.191
# 0         18.059         20.094          13.121           19.861    25.191
# 0         18.059         20.094          13.121           19.861    25.191
#
#    > 2000.00um    Clay    Silt    Sand     Community
# ...

# %%
cp.shape
# Out:
# (755, 15)

# %%
bb = join[join['Community'] == 'Blackbox']
bb.head()
# Out:
#         Site  < 0.060 um   0.06um-0.20um  0.20um-0.63um  0.06um-0.63um  \
# 151  BLA_001           0             0.0           1.92           1.92
# 151  BLA_001           0             0.0           1.92           1.92
# 151  BLA_001           0             0.0           1.92           1.92
# 151  BLA_001           0             0.0           1.92           1.92
# 151  BLA_001           0             0.0           1.92           1.92
#
#      0.63um-2.00um  2.00um-6.30um  6.30um-20.00um  20.00um-63.00um  >63.00um  \
# 151          13.62         21.268           20.14           26.306    16.747
# 151          13.62         21.268           20.14           26.306    16.747
# 151          13.62         21.268           20.14           26.306    16.747
# 151          13.62         21.268           20.14           26.306    16.747
# 151          13.62         21.268           20.14           26.306    16.747
#
#      > 2000.00um   Clay    Silt    Sand Community
# ...

# %%
bb.shape
# Out:
# (745, 15)

# %%
rr = join[join['Community'] == 'Redgum']
rr.head()
# Out:
#         Site  < 0.060 um   0.06um-0.20um  0.20um-0.63um  0.06um-0.63um  \
# 301  RRG_001           0             0.0          2.035          2.035
# 301  RRG_001           0             0.0          2.035          2.035
# 301  RRG_001           0             0.0          2.035          2.035
# 301  RRG_001           0             0.0          2.035          2.035
# 301  RRG_001           0             0.0          2.035          2.035
#
#      0.63um-2.00um  2.00um-6.30um  6.30um-20.00um  20.00um-63.00um  >63.00um  \
# 301         12.855          27.36          27.268           21.187     9.294
# 301         12.855          27.36          27.268           21.187     9.294
# 301         12.855          27.36          27.268           21.187     9.294
# 301         12.855          27.36          27.268           21.187     9.294
# 301         12.855          27.36          27.268           21.187     9.294
#
#      > 2000.00um    Clay    Silt  Sand Community
# ...

# %%
rr.shape
# Out:
# (750, 15)
