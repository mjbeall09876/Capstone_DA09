# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
soil = pd.read_excel('../data/nsw-assessment-of-soil-health.xlsx')
print(soil.shape)
soil.head(3)
# Out:
# (2255, 26)
#       Community       SiteID     Site  Rough  Resist  Resist_adjust  Broke  \
# 0  Cypress pine  CYP_001_000  CYP_001      1       4            1.0      2
# 1  Cypress pine  CYP_001_050  CYP_001      1       4            1.0      4
# 2  Cypress pine  CYP_001_100  CYP_001      1       4            1.0      4
#
#    Stab  Biocrust  Biocrust_code  ...  Litter_code  Litt_depth  Litt_Origin  \
# 0     4       5.0              2  ...            1         3.0          1.5
# 1     4      20.0              3  ...            2         4.0          1.5
# 2     4      10.0              2  ...            2         0.5          1.5
#
#    Litt_Incorp  Litt_Propn  Litt_Complex  Texture  Stability  Infiltration  \
# 0          1.0        95.0           1.5        2  54.107231     20.550760
# 1          1.0        30.0           3.0        2  63.944909     22.605836
# 2          1.0       100.0           3.0        2  63.944909     20.550760
#
#    Nutrients
# 0  15.116279
# 1  20.930233
# 2  16.279070
#
# [3 rows x 26 columns]

# %%
cp = soil[soil['Community'] == 'Cypress pine']
cp.head()
# Out:
#       Community       SiteID     Site  Rough  Resist  Resist_adjust  Broke  \
# 0  Cypress pine  CYP_001_000  CYP_001      1       4            1.0      2
# 1  Cypress pine  CYP_001_050  CYP_001      1       4            1.0      4
# 2  Cypress pine  CYP_001_100  CYP_001      1       4            1.0      4
# 3  Cypress pine  CYP_001_150  CYP_001      1       4            1.0      4
# 4  Cypress pine  CYP_001_200  CYP_001      1       4            1.0      3
#
#    Stab  Biocrust  Biocrust_code  ...  Litter_code  Litt_depth  Litt_Origin  \
# 0     4       5.0              2  ...            1         3.0          1.5
# 1     4      20.0              3  ...            2         4.0          1.5
# 2     4      10.0              2  ...            2         0.5          1.5
# 3     3      20.0              3  ...            1         0.5          1.5
# 4     4      30.0              3  ...            1         1.0          1.5
#
#    Litt_Incorp  Litt_Propn  Litt_Complex  Texture  Stability  Infiltration  \
# 0          1.0        95.0           1.5        2  54.107231     20.550760
# 1          1.0        30.0           3.0        2  63.944909     22.605836
# 2          1.0       100.0           3.0        2  63.944909     20.550760
# 3          1.0       100.0           1.5        2  59.026070     16.440608
# 4          1.0       100.0           1.5        2  56.566650     18.495684
#
#    Nutrients
# 0  15.116279
# 1  20.930233
# 2  16.279070
# 3  15.116279
# 4  15.116279
#
# [5 rows x 26 columns]

# %%
cp.shape
# Out:
# (755, 26)

# %%
bb = soil[soil['Community'] == 'Blackbox']
bb.head()
# Out:
#     Community       SiteID     Site  Rough  Resist  Resist_adjust  Broke  \
# 755  Blackbox  BLA_001_000  BLA_001      3       1           1.00      0
# 756  Blackbox  BLA_001_050  BLA_001      3       3           3.33      3
# 757  Blackbox  BLA_001_100  BLA_001      3       2           6.66      2
# 758  Blackbox  BLA_001_150  BLA_001      3       1           1.00      0
# 759  Blackbox  BLA_001_200  BLA_001      3       2           6.66      2
#
#      Stab  Biocrust  Biocrust_code  ...  Litter_code  Litt_depth  Litt_Origin  \
# 755     0       0.0              0  ...            2         3.0          1.5
# 756     3       0.0              0  ...            4         6.0          1.5
# 757     2       0.0              0  ...            4         3.0          1.5
# 758     0       0.0              0  ...            2         2.0          1.5
# 759     2       0.0              0  ...            1         2.0          1.5
#
#      Litt_Incorp  Litt_Propn  Litt_Complex  Texture  Stability  Infiltration  \
# 755          1.0        25.0           3.0        1  34.431874     12.330456
# 756          1.3        80.0           7.8        1  59.837678     27.394164
# 757          1.3        15.0           7.8        1  60.649287     30.127415
# 758          1.0        40.0           3.0        1  31.972455     10.275380
# 759          1.0       100.0           1.5        1  58.189867     26.017263
#
#      Nutrients
# 755  18.604651
# 756  29.767442
# 757  27.441860
# 758  16.279070
# 759  15.116279
#
# [5 rows x 26 columns]

# %%
bb.shape
# Out:
# (750, 26)

# %%
rr = soil[soil['Community'] == 'Redgum']
rr.head()
# Out:
#      Community       SiteID     Site  Rough  Resist  Resist_adjust  Broke  \
# 1505    Redgum  RRG_001_000  RRG_001      2       5           1.00      4
# 1506    Redgum  RRG_001_050  RRG_001      2       5           1.00      4
# 1507    Redgum  RRG_001_100  RRG_001      4       2           6.66      4
# 1508    Redgum  RRG_001_150  RRG_001      2       5           1.00      4
# 1509    Redgum  RRG_001_200  RRG_001      2       5           1.00      4
#
#       Stab  Biocrust  Biocrust_code  ...  Litter_code  Litt_depth  \
# 1505     4       0.0              0  ...            3        15.0
# 1506     4       0.0              0  ...            2        20.0
# 1507     4       0.0              0  ...            4        50.0
# 1508     4       0.0              0  ...            3        20.0
# 1509     4       0.0              0  ...            3        20.0
#
#       Litt_Origin  Litt_Incorp  Litt_Propn  Litt_Complex  Texture  Stability  \
# 1505          1.5          1.3        60.0          5.85        1  51.647811
# 1506          1.5          1.3        80.0          3.90        1  49.188392
# 1507          1.0          1.7        30.0          6.80        1  68.027545
# 1508          1.5          1.7        80.0          7.65        1  51.647811
# 1509          1.5          1.7        80.0          7.65        1  54.107231
#
#       Infiltration  Nutrients
# 1505     20.550760  20.581395
# 1506     18.495684  16.046512
# 1507     34.237567  27.441860
# 1508     20.550760  24.767442
# 1509     20.550760  24.767442
#
# [5 rows x 26 columns]

# %%
rr.shape
# Out:
# (750, 26)
